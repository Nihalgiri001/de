# %%
df=pd.read_csv(“iris.csv”)
dum = pd.get_dummies(df.<column_names>)

df1 = pd.concat([df,dum], axis=’columns’)




from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
iris=datasets.load_iris()
df=pd.DataFrame(data=iris.data, columns=iris.feature_names)
df[‘species’] = pd.Categorical.from_codes(iris.target, iris.target_names)
df1 = df
df1.species = le.fit_transform(df1.species)


df[‘petal_category’] = df.cut(df.petalwidthcm, bins=[0,1,2,2.5])
print(df[‘petal_category’])
print(df[‘petal_category’].value_counts())
