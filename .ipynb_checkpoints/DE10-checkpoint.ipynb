# %%
use booksdb
db.createCollection("books")

db.books.insertOne({title: "Harry Potter", author: "JK Rowling", price: 500})
db.books.find().pretty()

db.books.insertMany([
	{title: "Wings of fire", author: "APJ Abdul Kalam", price:250},
	{title: "1984", author: "George Orwell", price:300}
])
db.books.find()

db.books.find({price: {$eq: 300}})

db.books.updateOne(
	{title: "Harry Potter"},
	{$set: {price: 400}}
)
db.books.find().pretty()

db.books.updateMany(
	{price: {$lt: 400}},
	{$set: {price: 350}}
)
db.books.find().pretty()

db.books.deleteOne({title: "Harry Potter"})
db.books.find().pretty()

db.books.deleteMany({price: {$gt: 300}})
db.books.find().pretty()




#SVD
import sklearn
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt

iris=datasets.load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
#Before SVD
x=iris.data
y=iris.target
plt.scatter(x[:,0], x[:,1], c=y)
plt.title("BEFORE SVD")
plt.show()

#After SVD
U_iris, S_iris, VT_iris = np.linalg.svd(df, full_matrices=False)
plt.scatter(U_iris[:,0], U_iris[:,1], c=y)
plt.title("AFTER SVD")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
