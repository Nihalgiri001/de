# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# Load Auto MPG dataset
df = pd.read_csv("auto-mpg.csv")
print(df.head())
df.isnull().sum()

df.fillna(df.mean(numeric_only=True), inplace=True)

#Using percentile
num_df = df.select_dtypes(include='number')
lower = num_df.quantile(0.01)
upper = num_df.quantile(0.99)
df_percentile = df[
    ~((num_df < lower) | (num_df > upper)).any(axis=1)
]
print(df_percentile)

#Using IQR
lower = num_df.quantile(0.25)
upper = num_df.quantile(0.75)
df_IQR = df[
    ~((num_df < lower) | (num_df > upper)).any(axis=1)
]
print(df_IQR)


#Using Z score
z = np.abs(stats.zscore(num_df))
df_zscore = df[(z < 3).all(axis=1)]
print(df_zscore)


#Using Standard deviation
mean = num_df.mean()
std = num_df.std()

df_std = df[
    ~((num_df < (mean - 3*std)) | (num_df > (mean + 3*std))).any(axis=1)
]



# Replace missing horsepower with median
df['acceleration'].fillna(df['acceleration'].median(), inplace=True)

# Replace missing weight with mean
df['weight'].fillna(df['weight'].mean(), inplace=True)


df_capped = df.copy()

df_capped[num_df.columns] = df_capped[num_df.columns].clip(
    lower=num_df.quantile(0.05),
    upper=num_df.quantile(0.95),
    axis=1
)

print(df_capped)




# -------------------------------
# 1. Measure of Central Tendency
# -------------------------------

print("\nMean MPG:", df['mpg'].mean())
print("Median MPG:", df['mpg'].median())
print("Mode MPG:")
print(df['mpg'].mode())

# -------------------------------
# 2. Measures of Data Spread
# -------------------------------

print("\nRange:", df['mpg'].max() - df['mpg'].min())
print("Variance:", df['mpg'].var())
print("Standard Deviation:", df['mpg'].std())
# Out:
#    Unnamed: 0.1  Unnamed: 0   mpg  cylinders  displacement horsepower weight  \
# 0             0           0  18.0          8         307.0        130   3504
# 1             1           1  15.0          8         350.0        165   3693
# 2             2           2  47.0          8         318.0        150   3436
# 3             3           3  16.0          8         304.0        150   3433
# 4             4           4  17.0          8         302.0        140      ?
#
#    acceleration  model year  origin                   car name
# 0          12.0          70       1  chevrolet chevelle malibu
# 1          11.5          70       1          buick skylark 320
# 2          11.0          70       1         plymouth satellite
# 3          12.0          70       1              amc rebel sst
# 4          10.5          70       1                ford torino
#      Unnamed: 0.1  Unnamed: 0   mpg  cylinders  displacement horsepower  \
# 4               4           4  17.0          8         302.0        140
# 7               7           7  14.0          8         440.0        215
# 9               9           9  15.0          8         390.0        190
# 12             12          12  15.0          8         400.0        150
# 14             14          14  24.0          4         113.0         95
# ..            ...         ...   ...        ...           ...        ...
# 389           389         389  22.0          6         232.0        112
# 390           390         390  32.0          4         144.0         96
# 391           391         391  36.0          4         135.0         84
# 392           392         392  27.0          4         151.0         90
# 393           393         393  27.0          4         140.0         86
#
#     weight  acceleration  model year  origin               car name
# 4        ?     10.500000          70       1            ford torino
# 113   2472     14.000000          73       1
# 118   2158     15.500000          73       2
# 119   2582     14.000000          73       2
# 120   2868     15.500000          73       2
# 122   2660     14.000000          73       2
# 125   3102     16.500000          74       1
# 126   2875     17.000000          74       1
# 127   2901     16.000000          74       1
# 130   2451     16.500000          74       1
# 132   2542     17.000000          74       1
# 135   3613     16.500000          74       1
# 148   2246     14.000000          74       2
# 152   3264     16.000000          75       1
# 153   3459     16.000000          75       1
# 164   3039     15.000000          75       1
# 168   2639     17.000000          75       1
# 169   2914     16.000000          75       1
# 174   2984     14.500000          75       1
# 176   3211     17.000000          75       1
# 177   2694     15.000000          75       2
# 178   2957     17.000000          75       2
# 179   2945     14.500000          75       2
# 182   2464     15.500000          76       2
# 183   2220     16.900000          76       2
# 184   2572     14.900000          76       1
# 191   3233     15.400000          76       1
# 192   3353     14.500000          76       1
# 201   3645     16.200000          76       1
# 207   3150     15.700000          76       2
# 209   3270     15.468241          76       2
# 219   2300     15.500000          77       1
# 225   3520     16.400000          77       1
# 226   3425     16.900000          77       1
# 234   2740     16.000000          77       1
# 236   2755     15.800000          77       1
# 249   3365     15.500000          78       1
# 254   2965     15.800000          78       1
# 255   2720     15.400000          78       1
# 258   3380     15.800000          78       1
# 259   3070     16.700000          78       1
# 261   3410     15.100000          78       1
# 271   2745     16.700000          78       1
# 274   2830     15.900000          78       2
# 276   2795     15.700000          78       2
# 280   3245     15.400000          79       1
# 284   3360     16.600000          79       1
# 296   2670     15.000000          79       1
#
#                               car name
# 100                      ford maverick
# 101                    plymouth duster
# 107                        amc gremlin
# 113                   mercury capri v6
# 118                         opel manta
# 119                         audi 100ls
# 120                        volvo 144ea
# 122                          saab 99le
# 125                    plymouth duster
# 126                      ford maverick
# 127                         amc hornet
# 130                         ford pinto
# 132                     chevrolet vega
# 135         plymouth satellite sebring
# 148                        fiat 124 tc
# 152            plymouth valiant custom
# 153                     chevrolet nova
# 164                      buick skyhawk
# 168                         ford pinto
# 169                        amc gremlin
# 174                         ford pinto
# 176                          amc pacer
# 177                         audi 100ls
# 178                        peugeot 504
# 179                        volvo 244dl
# 182                           fiat 131
# 183                          opel 1900
# 184                           capri ii
# 191                   plymouth valiant
# 192                     chevrolet nova
# 201                 pontiac ventura sj
# 207                          volvo 245
# 209                        peugeot 504
# 219                  plymouth arrow gs
# 225                 chevrolet concours
# 226                      buick skylark
# 234              pontiac sunbird coupe
# 236                ford mustang ii 2+2
# 249  oldsmobile cutlass salon brougham
# 254               ford fairmont (auto)
# 255                ford fairmont (man)
# 258              buick century special
# 259                     mercury zephyr
# 261                    amc concord d/l
# 271                   plymouth sapporo
# 274                          audi 5000
# 276                         saab 99gle
# 280                  pontiac lemans v6
# 284                      dodge aspen 6
# 296                      amc spirit dl
#      Unnamed: 0.1  Unnamed: 0   mpg  cylinders  displacement horsepower  \
# 0               0           0  18.0          8         307.0        130
# 1               1           1  15.0          8         350.0        165
# 2               2           2  47.0          8         318.0        150
# 3               3           3  16.0          8         304.0        150
# 4               4           4  17.0          8         302.0        140
# ..            ...         ...   ...        ...           ...        ...
# 393           393         393  27.0          4         140.0         86
# 394           394         394  44.0          4          97.0         52
# 395           395         395  32.0          4         135.0         84
# 396           396         396  28.0          4         120.0         79
# 397           397         397  31.0          4         119.0         82
#
#     weight  acceleration  model year  origin                   car name
# 0     3504     12.000000          70       1  chevrolet chevelle malibu
# 1     3693     11.500000          70       1          buick skylark 320
# 2     3436     11.000000          70       1         plymouth satellite
# 3     3433     12.000000          70       1              amc rebel sst
# 4        ?     10.500000          70       1                ford torino
# ..     ...           ...         ...     ...                        ...
# 393   2790     15.600000          82       1            ford mustang gl
# 394   2130     15.501542          82       2                  vw pickup
# 395   2295     11.600000          82       1              dodge rampage
# 396   2625     18.600000          82       1                ford ranger
# 397   2720     19.400000          82       1                 chevy s-10
#
# [398 rows x 11 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 52
#      49 df['acceleration'].fillna(df['acceleration'].median(), inplace=True)
#      51 # Replace missing weight with mean
# ---> 52 df['weight'].fillna(df['weight'].mean(), inplace=True)
#      55 df_capped = df.copy()
#      57 df_capped[num_df.columns] = df_capped[num_df.columns].clip(
#      58     lower=num_df.quantile(0.05),
#      59     upper=num_df.quantile(0.95),
#      60     axis=1
#      61 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '3504369334363433?43414354431244253850356336093761308623722833?...?...?43604054360539401925197519152670353039003190342022002150202021302670259527002556214419682120201926782870300333812188271125422434226521102800211020852335?' to numeric
