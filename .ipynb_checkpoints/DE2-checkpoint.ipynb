# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("iris.csv")
print(df.columns)
df=df.rename(columns={"Id" : "Id1"})
print(df.columns)
df1=df2=df
df3=pd.concat([df1,df2]).reset_index(drop=True)
print(df3)
df1=df2=df
df3=pd.concat([df1,df2], axis=1).reset_index(drop=True)
print(df3)
print(df.isnull())
print(df.isnull().sum())


#Feature Extraction:
iris = pd.read_csv("iris.csv").drop(columns='Species')
sns.heatmap(iris.corr(method='pearson').drop(['Id'], axis=1).drop(['Id'], axis=0), annot=True)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# Index(['Id1', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
#      Id1  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 295  146            6.7           3.0            5.2           2.3
# 296  147            6.3           2.5            5.0           1.9
# 297  148            6.5           3.0            5.2           2.0
# ...
