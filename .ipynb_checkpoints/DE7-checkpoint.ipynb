# %%
hadoop version
hdfs dfs -mkdir /hadooplab
echo "Test file" > file1.txt
cat file1.txt
hdfs dfs -put file1.txt /hadooplab



iris = datasets.load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
print(df.head())
print(df.mean())
print(df.median())
print(df.mode())

print(df.std())
print(df.var())

print(df.quantile(0.25))
print(df.quantile(0.50))
print(df.quantile(0.75))

IQR = df.quantile(0.75) - df.quantile(0.25)
print(IQR)
